# %%
import pandas as pd

# %%
df=pd.read_csv("plottwistNovels.csv")

# %%
df
# Out:
#      Rank                                               Name  \
# 0       1                                         Fight Club
# 1       2                           And Then There Were None
# 2       3                                          Gone Girl
# 3       4  Harry Potter and the Deathly Hallows (Harry Po...
# 4       5                    Ender's Game (Ender's Saga, #1)
# ..    ...                                                ...
# 403   404                                       Huid en haar
# 404   404                               The Couple Next Door
# 405   406                          The Clockmaker's Daughter
# 406   407                                 Small Great Things
# 407   408                                        Pretty Ugly
#
#                Author  Average Rating  Number Of Ratings
# 0     Chuck Palahniuk            4.19             538411
# 1     Agatha Christie            4.27            1058841
# 2       Gillian Flynn            4.10            2669986
# ...

# %%
fourPlus=(df['Average Rating']>=4)

# %%
df[fourPlus]
# Out:
#      Rank                                               Name  \
# 0       1                                         Fight Club
# 1       2                           And Then There Were None
# 2       3                                          Gone Girl
# 3       4  Harry Potter and the Deathly Hallows (Harry Po...
# 4       5                    Ender's Game (Ender's Saga, #1)
# ..    ...                                                ...
# 379   376  Bound by Oath and Heart: Arsinoëphorus Allianc...
# 383   383  The Burden of Proof (Kindle County Legal Thril...
# 384   383                                 The Sun Down Motel
# 401   402                                 Rich Man, Poor Man
# 406   407                                 Small Great Things
#
#                Author  Average Rating  Number Of Ratings
# 0     Chuck Palahniuk            4.19             538411
# 1     Agatha Christie            4.27            1058841
# 2       Gillian Flynn            4.10            2669986
# ...

# %%
rated=df[fourPlus]

# %%
tenK=(df['Number Of Ratings']>10000)

# %%
(df[tenK])[fourPu]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 (df[tenK])[four]
#
# NameError: name 'four' is not defined
